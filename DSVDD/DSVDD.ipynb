# %%
import numpy as np
import json
from sklearn.metrics import f1_score, roc_auc_score
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader 
import matplotlib.pyplot as plt

# %%
class Linear_BN_leakyReLU(nn.Module):
    """
    A nn.Module that consists of a Linear layer followed by BatchNorm1d and a leaky ReLu activation
    """

    def __init__(self, in_features, out_features, bias=False, eps=1e-04):
        super(Linear_BN_leakyReLU, self).__init__()

        self.linear = nn.Linear(in_features, out_features, bias=bias)
        self.bn = nn.BatchNorm1d(out_features, eps=eps, affine=bias)

    def forward(self, x):
        return F.leaky_relu(self.bn(self.linear(x)))

# %%
class MLP(nn.Module):
    
    def __init__(self, x_dim, h_dims=[128, 64], rep_dim=32, bias=False):
        super(MLP, self).__init__()

        self.rep_dim = rep_dim # representation dimensionality, i.e, dim of the code layer or last layer.

        neurons = [x_dim, *h_dims]
        layers = [Linear_BN_leakyReLU(neurons[i - 1], neurons[i], bias=bias) for i in range(1, len(neurons))]

        self.hidden = nn.ModuleList(layers)
        self.code = nn.Linear(h_dims[-1], rep_dim, bias=bias)

    def forward(self, x):
        x = x.view(int(x.size(0)), -1)
        for layer in self.hidden:
            x = layer(x)
        return self.code(x)


class MLP_Decoder(nn.Module):

    def __init__(self, x_dim, h_dims=[64, 128], rep_dim=32, bias=False):
        super(MLP_Decoder, self).__init__()

        self.rep_dim = rep_dim

        neurons = [rep_dim, *h_dims]
        layers = [Linear_BN_leakyReLU(neurons[i - 1], neurons[i], bias=bias) for i in range(1, len(neurons))]

        self.hidden = nn.ModuleList(layers)
        self.reconstruction = nn.Linear(h_dims[-1], x_dim, bias=bias)
        self.output_activation = nn.Sigmoid()

    def forward(self, x):
        x = x.view(int(x.size(0)), -1)
        for layer in self.hidden:
            x = layer(x)
        x = self.reconstruction(x)
        return self.output_activation(x)


class MLP_AE(nn.Module):

    def __init__(self, x_dim, h_dims=[128, 64], rep_dim=32, bias=False):
        super(MLP_AE, self).__init__()

        self.rep_dim = rep_dim
        self.encoder = MLP(x_dim, h_dims, rep_dim, bias)
        self.decoder = MLP_Decoder(x_dim, list(reversed(h_dims)), rep_dim, bias)

    def forward(self, x):
        x = self.encoder(x)
        x = self.decoder(x)
        return x

# %%
def build_network(net_name, ae_net=None):
    """Builds the neural network."""

    implemented_networks = ('arrhythmia_mlp', 'cardio_mlp', 'satellite_mlp', 'satimage-2_mlp', 'shuttle_mlp',
                            'thyroid_mlp')
    assert net_name in implemented_networks

    net = None

    if net_name == 'arrhythmia_mlp':
        net = MLP(x_dim=274, h_dims=[128, 64], rep_dim=32, bias=False)
        
    if net_name == 'thyroid_mlp':
        net = MLP(x_dim=6, h_dims=[32, 16], rep_dim=4, bias=False)

    # if net_name == 'cardio_mlp':
    #     net = MLP(x_dim=21, h_dims=[32, 16], rep_dim=8, bias=False)
    # if net_name == 'satellite_mlp':
    #     net = MLP(x_dim=36, h_dims=[32, 16], rep_dim=8, bias=False)
    # if net_name == 'satimage-2_mlp':
    #     net = MLP(x_dim=36, h_dims=[32, 16], rep_dim=8, bias=False)
    # if net_name == 'shuttle_mlp':
    #     net = MLP(x_dim=9, h_dims=[32, 16], rep_dim=8, bias=False)

    return net


def build_autoencoder(net_name):
    """Builds the corresponding autoencoder network."""

    implemented_networks = ('arrhythmia_mlp', 'cardio_mlp', 'satellite_mlp', 'satimage-2_mlp', 'shuttle_mlp',
                            'thyroid_mlp')

    assert net_name in implemented_networks

    ae_net = None

    if net_name == 'arrhythmia_mlp':
        ae_net = MLP_AE(x_dim=274, h_dims=[128, 64], rep_dim=32, bias=False)
        
    if net_name == 'thyroid_mlp':
        ae_net = MLP_AE(x_dim=6, h_dims=[32, 16], rep_dim=4, bias=False)

    # if net_name == 'cardio_mlp':
    #     ae_net = MLP_AE(x_dim=21, h_dims=[32, 16], rep_dim=8, bias=False)
    # if net_name == 'satellite_mlp':
    #     ae_net = MLP_AE(x_dim=36, h_dims=[32, 16], rep_dim=8, bias=False)
    # if net_name == 'satimage-2_mlp':
    #     ae_net = MLP_AE(x_dim=36, h_dims=[32, 16], rep_dim=8, bias=False)
    # if net_name == 'shuttle_mlp':
    #     ae_net = MLP_AE(x_dim=9, h_dims=[32, 16], rep_dim=8, bias=False)

    return ae_net

# %%
from dsvdd_trainer import AETrainer, DeepSVDDTrainer

# %%
class DeepSVDD(object):
    """A class for the Deep SVDD method.
    Attributes:
        objective: A string specifying the Deep SVDD objective (either 'one-class' or 'soft-boundary').
        nu: Deep SVDD hyperparameter nu (must be 0 < nu <= 1).
        R: Hypersphere radius R.
        c: Hypersphere center c.
        net_name: A string indicating the name of the neural network to use.
        net: The neural network \phi.
        ae_net: The autoencoder network corresponding to \phi for network weights pretraining.
        trainer: DeepSVDDTrainer to train a Deep SVDD model.
        optimizer_name: A string indicating the optimizer to use for training the Deep SVDD network.
        ae_trainer: AETrainer to train an autoencoder in pretraining.
        ae_optimizer_name: A string indicating the optimizer to use for pretraining the autoencoder.
        results: A dictionary to save the results.
    """

    def __init__(self, objective = 'one-class', nu = 0.1):
        """Inits DeepSVDD with one of the two objectives and hyperparameter nu."""

        assert objective in ('one-class', 'soft-boundary'), "Objective must be either 'one-class' or 'soft-boundary'."
        self.objective = objective
        assert (0 < nu) & (nu <= 1), "For hyperparameter nu, it must hold: 0 < nu <= 1."
        self.nu = nu
        self.R = 0.0  # hypersphere radius R
        self.c = None  # hypersphere center c

        self.net_name = None
        self.net = None  # neural network \phi

        self.trainer = None
        self.optimizer_name = None

        self.ae_net = None  # autoencoder network for pretraining
        self.ae_trainer = None
        self.ae_optimizer_name = None

        self.results = {
            'train_time': None,
            'test_auc': None,
            'test_time': None,
            'test_scores': None,
        }

    def set_network(self, net_name):
        """Builds the neural network \phi."""
        self.net_name = net_name
        self.net = build_network(net_name)

    def train(self, data_loader, optimizer_name = 'adam', lr = 0.001, n_epochs = 50,
              lr_milestones = (), batch_size = 128, weight_decay = 1e-6, device = 'cuda',
              n_jobs_dataloader = 0):
        """Trains the Deep SVDD model on the training data."""

        self.optimizer_name = optimizer_name
        self.trainer = DeepSVDDTrainer(self.objective, self.R, self.c, self.nu, optimizer_name, lr=lr,
                                       n_epochs=n_epochs, lr_milestones=lr_milestones, batch_size=batch_size,
                                       weight_decay=weight_decay, device=device, n_jobs_dataloader=n_jobs_dataloader)
        # Get the model
        self.net, self.loss_plot = self.trainer.train(data_loader, self.net)
        self.R = float(self.trainer.R.cpu().data.numpy())  # get float
        self.c = self.trainer.c.cpu().data.numpy().tolist()  # get list
        self.results['train_time'] = self.trainer.train_time

    def test(self, data_loader, device = 'cuda', n_jobs_dataloader = 0):
        """Tests the Deep SVDD model on the test data."""

        if self.trainer is None:
            self.trainer = DeepSVDDTrainer(self.objective, self.R, self.c, self.nu,
                                           device=device, n_jobs_dataloader=n_jobs_dataloader)

        self.trainer.test(data_loader, self.net)
        # Get results
        self.results['test_auc'] = self.trainer.test_auc
        self.results['test_time'] = self.trainer.test_time
        self.results['test_scores'] = self.trainer.test_scores

    def pretrain(self, train_loader, test_loader, optimizer_name = 'adam', lr = 0.001, n_epochs = 100,
                 lr_milestones = (), batch_size = 128, weight_decay = 1e-6, device = 'cuda',
                 n_jobs_dataloader = 0):
        """Pretrains the weights for the Deep SVDD network \phi via autoencoder."""

        self.ae_net = build_autoencoder(self.net_name)
        self.ae_optimizer_name = optimizer_name
        self.ae_trainer = AETrainer(optimizer_name, lr=lr, n_epochs=n_epochs, lr_milestones=lr_milestones,
                                    batch_size=batch_size, weight_decay=weight_decay, device=device,
                                    n_jobs_dataloader=n_jobs_dataloader)
        self.ae_net, self.ae_loss_plot = self.ae_trainer.train(train_loader, self.ae_net)
        self.ae_trainer.test(test_loader, self.ae_net)
        self.init_network_weights_from_pretraining()

    def init_network_weights_from_pretraining(self):
        """Initialize the Deep SVDD network weights from the encoder weights of the pretraining autoencoder."""

        net_dict = self.net.state_dict()
        ae_net_dict = self.ae_net.state_dict()

        # Filter out decoder network keys
        ae_net_dict = {k: v for k, v in ae_net_dict.items() if k in net_dict}
        # Overwrite values in the existing state_dict
        net_dict.update(ae_net_dict)
        # Load the new state_dict
        self.net.load_state_dict(net_dict)

    def save_model(self, export_model, save_ae=True):
        """Save Deep SVDD model to export_model."""

        net_dict = self.net.state_dict()
        ae_net_dict = self.ae_net.state_dict() if save_ae else None

        torch.save({'R': self.R,
                    'c': self.c,
                    'net_dict': net_dict,
                    'ae_net_dict': ae_net_dict}, export_model)

    def load_model(self, model_path, load_ae=False):
        """Load Deep SVDD model from model_path."""

        model_dict = torch.load(model_path)

        self.R = model_dict['R']
        self.c = model_dict['c']
        self.net.load_state_dict(model_dict['net_dict'])
        if load_ae:
            if self.ae_net is None:
                self.ae_net = build_autoencoder(self.net_name)
            self.ae_net.load_state_dict(model_dict['ae_net_dict'])

    def save_results(self, export_json):
        """Save results dict to a JSON-file."""
        with open(export_json, 'w') as fp:
            json.dump(self.results, fp)

# %%
sys.path.append('..')
import datasets.load_tabular as NAD

# %%
config = {
    "objective": 'one-class',
    "nu": 0.01,
    "net_name": 'arrhythmia_mlp',
    "ae_optimizer_name": 'adam',
    "ae_lr": 0.01,
    "ae_n_epochs": 500,
    "ae_lr_milestones": [50, 250, 500],
    "ae_batch_size": 50,
    "ae_weight_decay": 1e-4,
    "optimizer_name": 'adam',
    "lr": 0.01,
    "n_epochs": 500,
    "lr_milestones": [50, 250, 500],
    "batch_size": 50,
    "weight_decay": 1e-5,
    "n_jobs_dataloader": 0,
    "export_path": '/home/sewon/anomaly_detection/DSVDD',
    "pretrain": True,
    "num_threads": 0    
}

# %%
 # Default device to 'cpu' if cuda is not available
if not torch.cuda.is_available():
    device = 'cpu'
else:
    device = 'cuda'
# Set the number of threads used for parallelizing CPU operations
num_threads = config['num_threads']
if num_threads > 0:
    torch.set_num_threads(num_threads)

# %%
# Initialize DeepSVDD model and set neural network phi
deepSVDD = DeepSVDD(config['objective'], config['nu'])
deepSVDD.set_network(config['net_name'])

# %%
arrhy_train_X, arrhy_train_y, arrhy_test_X, arrhy_test_y = NAD.Arrhythmia_train_test_split('/home/sewon/anomaly_detection/datasets/')
train_data = TensorDataset(torch.FloatTensor(arrhy_train_X), torch.FloatTensor(arrhy_train_y))
train_loader = DataLoader(dataset = train_data, batch_size=config['batch_size'], shuffle=True)
test_data = TensorDataset(torch.FloatTensor(arrhy_test_X), torch.FloatTensor(arrhy_test_y))
test_loader = DataLoader(dataset = test_data, batch_size=config['batch_size'], shuffle=False)

# %%
if config["pretrain"]:
    # Pretrain model on dataset (via autoencoder)
    deepSVDD.pretrain(train_loader = train_loader, test_loader = test_loader,
                     optimizer_name=config['ae_optimizer_name'],
                     lr=config['ae_lr'],
                     n_epochs=config['ae_n_epochs'],
                     lr_milestones=config['ae_lr_milestones'],
                     batch_size=config['ae_batch_size'],
                     weight_decay=config['ae_weight_decay'],
                     device=device,
                     n_jobs_dataloader=config['n_jobs_dataloader'])
# Out:
# Starting pretraining...
# /home/sewon/anaconda3/envs/venvs/lib/python3.9/site-packages/torch/optim/lr_scheduler.py:418: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   warnings.warn("To get the last learning rate computed by the scheduler, "
#   LR scheduler: new learning rate is 0.0001
#   LR scheduler: new learning rate is 1e-05
# Pretraining Time: 4.865s
# Finished pretraining.
# Testing autoencoder...
# Test Loss: 1264.203573
# Test AUC: 55.86%
# Test Time: 0.005s
# Finished testing autoencoder.

# %%
def plot_loss_moment(losses):
    _, ax = plt.subplots(figsize=(8, 3), dpi=80)
    ax.plot(losses, 'blue', label='train', linewidth=1)
    ax.set_title('Loss change in training')
    ax.set_ylabel('Loss')
    ax.set_xlabel('Iteration')
    ax.legend(loc='upper right')
    # plt.savefig(os.path.join(config['img_dir'], 'loss_dagmm.png'))

# %%
plot_loss_moment(deepSVDD.ae_loss_plot)

# %%
deepSVDD.train(train_loader,
              optimizer_name=config['optimizer_name'],
              lr=config['lr'],
              n_epochs=config['n_epochs'],
              lr_milestones=config['lr_milestones'],
              batch_size=config['batch_size'],
              weight_decay=config['weight_decay'],
              device=device,
              n_jobs_dataloader=config['n_jobs_dataloader'])
# Out:
# Initializing center c...
# Center c initialized.
# Starting training...
# | Epoch: 001/500 | Train Time: 0.010s | Train Loss: 228.798965 |
# | Epoch: 002/500 | Train Time: 0.009s | Train Loss: 121.443125 |
# | Epoch: 003/500 | Train Time: 0.009s | Train Loss: 59.336270 |
# | Epoch: 004/500 | Train Time: 0.009s | Train Loss: 30.252886 |
# | Epoch: 005/500 | Train Time: 0.008s | Train Loss: 17.232923 |
# | Epoch: 006/500 | Train Time: 0.008s | Train Loss: 10.458542 |
# | Epoch: 007/500 | Train Time: 0.007s | Train Loss: 6.777828 |
# | Epoch: 008/500 | Train Time: 0.006s | Train Loss: 4.531614 |
# | Epoch: 009/500 | Train Time: 0.006s | Train Loss: 3.564690 |
# | Epoch: 010/500 | Train Time: 0.006s | Train Loss: 3.173565 |
# | Epoch: 011/500 | Train Time: 0.006s | Train Loss: 2.378714 |
# | Epoch: 012/500 | Train Time: 0.006s | Train Loss: 2.391538 |
# | Epoch: 013/500 | Train Time: 0.006s | Train Loss: 1.921255 |
# | Epoch: 014/500 | Train Time: 0.006s | Train Loss: 1.407686 |
# | Epoch: 015/500 | Train Time: 0.006s | Train Loss: 1.121350 |
# | Epoch: 016/500 | Train Time: 0.006s | Train Loss: 1.327888 |
# | Epoch: 017/500 | Train Time: 0.006s | Train Loss: 0.869977 |
# | Epoch: 018/500 | Train Time: 0.006s | Train Loss: 0.737018 |
# | Epoch: 019/500 | Train Time: 0.006s | Train Loss: 1.150630 |
# | Epoch: 020/500 | Train Time: 0.006s | Train Loss: 0.844294 |
# | Epoch: 021/500 | Train Time: 0.006s | Train Loss: 1.036144 |
# | Epoch: 022/500 | Train Time: 0.006s | Train Loss: 0.595794 |
# | Epoch: 023/500 | Train Time: 0.006s | Train Loss: 0.895235 |
# | Epoch: 024/500 | Train Time: 0.006s | Train Loss: 0.960931 |
# | Epoch: 025/500 | Train Time: 0.006s | Train Loss: 1.158681 |
# | Epoch: 026/500 | Train Time: 0.005s | Train Loss: 0.650282 |
# | Epoch: 027/500 | Train Time: 0.005s | Train Loss: 0.911469 |
# | Epoch: 028/500 | Train Time: 0.005s | Train Loss: 0.552178 |
# | Epoch: 029/500 | Train Time: 0.005s | Train Loss: 0.707168 |
# | Epoch: 030/500 | Train Time: 0.005s | Train Loss: 0.822385 |
# | Epoch: 031/500 | Train Time: 0.006s | Train Loss: 0.938694 |
# | Epoch: 032/500 | Train Time: 0.006s | Train Loss: 0.706265 |
# | Epoch: 033/500 | Train Time: 0.005s | Train Loss: 0.593619 |
# | Epoch: 034/500 | Train Time: 0.005s | Train Loss: 0.508982 |
# | Epoch: 035/500 | Train Time: 0.005s | Train Loss: 0.716820 |
# | Epoch: 036/500 | Train Time: 0.005s | Train Loss: 0.545404 |
# | Epoch: 037/500 | Train Time: 0.005s | Train Loss: 0.796430 |
# | Epoch: 038/500 | Train Time: 0.005s | Train Loss: 0.957279 |
# | Epoch: 039/500 | Train Time: 0.005s | Train Loss: 0.733525 |
# | Epoch: 040/500 | Train Time: 0.005s | Train Loss: 0.972400 |
# | Epoch: 041/500 | Train Time: 0.005s | Train Loss: 0.650798 |
# | Epoch: 042/500 | Train Time: 0.005s | Train Loss: 0.871224 |
# | Epoch: 043/500 | Train Time: 0.005s | Train Loss: 0.771900 |
# | Epoch: 044/500 | Train Time: 0.005s | Train Loss: 0.580046 |
# | Epoch: 045/500 | Train Time: 0.005s | Train Loss: 0.623516 |
# | Epoch: 046/500 | Train Time: 0.005s | Train Loss: 0.579945 |
# | Epoch: 047/500 | Train Time: 0.005s | Train Loss: 0.615230 |
# | Epoch: 048/500 | Train Time: 0.005s | Train Loss: 0.561493 |
# | Epoch: 049/500 | Train Time: 0.005s | Train Loss: 0.552532 |
# | Epoch: 050/500 | Train Time: 0.005s | Train Loss: 0.518660 |
#   LR scheduler: new learning rate is 0.0001
# | Epoch: 051/500 | Train Time: 0.006s | Train Loss: 0.486966 |
# | Epoch: 052/500 | Train Time: 0.005s | Train Loss: 0.409714 |
# | Epoch: 053/500 | Train Time: 0.005s | Train Loss: 0.352813 |
# | Epoch: 054/500 | Train Time: 0.005s | Train Loss: 0.226737 |
# | Epoch: 055/500 | Train Time: 0.005s | Train Loss: 0.458007 |
# | Epoch: 056/500 | Train Time: 0.005s | Train Loss: 0.271992 |
# | Epoch: 057/500 | Train Time: 0.005s | Train Loss: 0.347576 |
# | Epoch: 058/500 | Train Time: 0.005s | Train Loss: 0.270691 |
# | Epoch: 059/500 | Train Time: 0.005s | Train Loss: 0.284024 |
# | Epoch: 060/500 | Train Time: 0.005s | Train Loss: 0.309142 |
# | Epoch: 061/500 | Train Time: 0.005s | Train Loss: 0.318671 |
# | Epoch: 062/500 | Train Time: 0.006s | Train Loss: 0.284019 |
# | Epoch: 063/500 | Train Time: 0.005s | Train Loss: 0.355475 |
# | Epoch: 064/500 | Train Time: 0.005s | Train Loss: 0.267215 |
# | Epoch: 065/500 | Train Time: 0.005s | Train Loss: 0.325601 |
# | Epoch: 066/500 | Train Time: 0.005s | Train Loss: 0.414155 |
# | Epoch: 067/500 | Train Time: 0.005s | Train Loss: 0.311863 |
# | Epoch: 068/500 | Train Time: 0.005s | Train Loss: 0.264193 |
# | Epoch: 069/500 | Train Time: 0.005s | Train Loss: 0.305688 |
# /home/sewon/anaconda3/envs/venvs/lib/python3.9/site-packages/torch/optim/lr_scheduler.py:418: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   warnings.warn("To get the last learning rate computed by the scheduler, "
# | Epoch: 070/500 | Train Time: 0.006s | Train Loss: 0.271526 |
# | Epoch: 071/500 | Train Time: 0.006s | Train Loss: 0.287517 |
# | Epoch: 072/500 | Train Time: 0.005s | Train Loss: 0.484717 |
# | Epoch: 073/500 | Train Time: 0.005s | Train Loss: 0.326662 |
# | Epoch: 074/500 | Train Time: 0.005s | Train Loss: 0.338604 |
# | Epoch: 075/500 | Train Time: 0.005s | Train Loss: 0.218344 |
# | Epoch: 076/500 | Train Time: 0.005s | Train Loss: 0.397823 |
# | Epoch: 077/500 | Train Time: 0.005s | Train Loss: 0.329546 |
# | Epoch: 078/500 | Train Time: 0.005s | Train Loss: 0.433395 |
# | Epoch: 079/500 | Train Time: 0.005s | Train Loss: 0.334496 |
# | Epoch: 080/500 | Train Time: 0.005s | Train Loss: 0.348299 |
# | Epoch: 081/500 | Train Time: 0.005s | Train Loss: 0.275139 |
# | Epoch: 082/500 | Train Time: 0.006s | Train Loss: 0.314288 |
# | Epoch: 083/500 | Train Time: 0.005s | Train Loss: 0.242156 |
# | Epoch: 084/500 | Train Time: 0.005s | Train Loss: 0.532947 |
# | Epoch: 085/500 | Train Time: 0.005s | Train Loss: 0.228013 |
# | Epoch: 086/500 | Train Time: 0.005s | Train Loss: 0.211192 |
# | Epoch: 087/500 | Train Time: 0.005s | Train Loss: 0.343846 |
# | Epoch: 088/500 | Train Time: 0.005s | Train Loss: 0.259184 |
# | Epoch: 089/500 | Train Time: 0.006s | Train Loss: 0.502225 |
# | Epoch: 090/500 | Train Time: 0.005s | Train Loss: 0.288986 |
# | Epoch: 091/500 | Train Time: 0.005s | Train Loss: 0.213373 |
# | Epoch: 092/500 | Train Time: 0.006s | Train Loss: 0.264004 |
# | Epoch: 093/500 | Train Time: 0.006s | Train Loss: 0.218772 |
# | Epoch: 094/500 | Train Time: 0.005s | Train Loss: 0.281236 |
# | Epoch: 095/500 | Train Time: 0.005s | Train Loss: 0.202260 |
# | Epoch: 096/500 | Train Time: 0.005s | Train Loss: 0.262091 |
# | Epoch: 097/500 | Train Time: 0.005s | Train Loss: 0.249344 |
# | Epoch: 098/500 | Train Time: 0.005s | Train Loss: 0.294233 |
# | Epoch: 099/500 | Train Time: 0.005s | Train Loss: 0.349808 |
# | Epoch: 100/500 | Train Time: 0.005s | Train Loss: 0.289200 |
# | Epoch: 101/500 | Train Time: 0.005s | Train Loss: 0.283683 |
# | Epoch: 102/500 | Train Time: 0.005s | Train Loss: 0.274426 |
# | Epoch: 103/500 | Train Time: 0.005s | Train Loss: 0.310201 |
# | Epoch: 104/500 | Train Time: 0.005s | Train Loss: 0.251738 |
# | Epoch: 105/500 | Train Time: 0.005s | Train Loss: 0.256934 |
# | Epoch: 106/500 | Train Time: 0.005s | Train Loss: 0.208763 |
# | Epoch: 107/500 | Train Time: 0.005s | Train Loss: 0.241171 |
# | Epoch: 108/500 | Train Time: 0.005s | Train Loss: 0.267267 |
# | Epoch: 109/500 | Train Time: 0.005s | Train Loss: 0.186325 |
# | Epoch: 110/500 | Train Time: 0.006s | Train Loss: 0.359433 |
# | Epoch: 111/500 | Train Time: 0.005s | Train Loss: 0.305827 |
# | Epoch: 112/500 | Train Time: 0.005s | Train Loss: 0.338836 |
# | Epoch: 113/500 | Train Time: 0.005s | Train Loss: 0.224717 |
# | Epoch: 114/500 | Train Time: 0.005s | Train Loss: 0.210594 |
# | Epoch: 115/500 | Train Time: 0.005s | Train Loss: 0.189196 |
# | Epoch: 116/500 | Train Time: 0.005s | Train Loss: 0.252828 |
# | Epoch: 117/500 | Train Time: 0.005s | Train Loss: 0.287171 |
# | Epoch: 118/500 | Train Time: 0.005s | Train Loss: 0.320254 |
# | Epoch: 119/500 | Train Time: 0.005s | Train Loss: 0.357282 |
# | Epoch: 120/500 | Train Time: 0.005s | Train Loss: 0.310969 |
# | Epoch: 121/500 | Train Time: 0.005s | Train Loss: 0.218352 |
# | Epoch: 122/500 | Train Time: 0.005s | Train Loss: 0.301381 |
# | Epoch: 123/500 | Train Time: 0.005s | Train Loss: 0.256889 |
# | Epoch: 124/500 | Train Time: 0.005s | Train Loss: 0.390388 |
# | Epoch: 125/500 | Train Time: 0.005s | Train Loss: 0.201831 |
# | Epoch: 126/500 | Train Time: 0.005s | Train Loss: 0.275440 |
# | Epoch: 127/500 | Train Time: 0.005s | Train Loss: 0.279453 |
# | Epoch: 128/500 | Train Time: 0.005s | Train Loss: 0.198489 |
# | Epoch: 129/500 | Train Time: 0.005s | Train Loss: 0.281853 |
# | Epoch: 130/500 | Train Time: 0.005s | Train Loss: 0.261440 |
# | Epoch: 131/500 | Train Time: 0.005s | Train Loss: 0.226384 |
# | Epoch: 132/500 | Train Time: 0.005s | Train Loss: 0.218634 |
# | Epoch: 133/500 | Train Time: 0.005s | Train Loss: 0.333952 |
# | Epoch: 134/500 | Train Time: 0.005s | Train Loss: 0.365589 |
# | Epoch: 135/500 | Train Time: 0.005s | Train Loss: 0.244587 |
# | Epoch: 136/500 | Train Time: 0.005s | Train Loss: 0.290155 |
# | Epoch: 137/500 | Train Time: 0.005s | Train Loss: 0.281693 |
# | Epoch: 138/500 | Train Time: 0.005s | Train Loss: 0.327963 |
# | Epoch: 139/500 | Train Time: 0.005s | Train Loss: 0.281697 |
# | Epoch: 140/500 | Train Time: 0.005s | Train Loss: 0.326827 |
# | Epoch: 141/500 | Train Time: 0.005s | Train Loss: 0.327201 |
# | Epoch: 142/500 | Train Time: 0.005s | Train Loss: 0.300294 |
# | Epoch: 143/500 | Train Time: 0.005s | Train Loss: 0.341896 |
# | Epoch: 144/500 | Train Time: 0.005s | Train Loss: 0.178246 |
# | Epoch: 145/500 | Train Time: 0.005s | Train Loss: 0.374450 |
# | Epoch: 146/500 | Train Time: 0.005s | Train Loss: 0.254295 |
# | Epoch: 147/500 | Train Time: 0.005s | Train Loss: 0.195041 |
# | Epoch: 148/500 | Train Time: 0.005s | Train Loss: 0.237807 |
# | Epoch: 149/500 | Train Time: 0.005s | Train Loss: 0.229136 |
# | Epoch: 150/500 | Train Time: 0.006s | Train Loss: 0.329872 |
# | Epoch: 151/500 | Train Time: 0.005s | Train Loss: 0.206432 |
# | Epoch: 152/500 | Train Time: 0.005s | Train Loss: 0.179595 |
# | Epoch: 153/500 | Train Time: 0.005s | Train Loss: 0.355504 |
# | Epoch: 154/500 | Train Time: 0.005s | Train Loss: 0.263169 |
# | Epoch: 155/500 | Train Time: 0.005s | Train Loss: 0.332809 |
# | Epoch: 156/500 | Train Time: 0.005s | Train Loss: 0.182297 |
# | Epoch: 157/500 | Train Time: 0.005s | Train Loss: 0.372913 |
# | Epoch: 158/500 | Train Time: 0.005s | Train Loss: 0.204460 |
# | Epoch: 159/500 | Train Time: 0.005s | Train Loss: 0.257634 |
# | Epoch: 160/500 | Train Time: 0.005s | Train Loss: 0.163462 |
# | Epoch: 161/500 | Train Time: 0.005s | Train Loss: 0.435083 |
# | Epoch: 162/500 | Train Time: 0.005s | Train Loss: 0.328096 |
# | Epoch: 163/500 | Train Time: 0.005s | Train Loss: 0.282067 |
# | Epoch: 164/500 | Train Time: 0.005s | Train Loss: 0.214024 |
# | Epoch: 165/500 | Train Time: 0.005s | Train Loss: 0.226476 |
# | Epoch: 166/500 | Train Time: 0.005s | Train Loss: 0.162366 |
# | Epoch: 167/500 | Train Time: 0.005s | Train Loss: 0.226084 |
# | Epoch: 168/500 | Train Time: 0.005s | Train Loss: 0.191436 |
# | Epoch: 169/500 | Train Time: 0.005s | Train Loss: 0.323168 |
# | Epoch: 170/500 | Train Time: 0.005s | Train Loss: 0.332745 |
# | Epoch: 171/500 | Train Time: 0.005s | Train Loss: 0.257918 |
# | Epoch: 172/500 | Train Time: 0.005s | Train Loss: 0.211489 |
# | Epoch: 173/500 | Train Time: 0.005s | Train Loss: 0.243035 |
# | Epoch: 174/500 | Train Time: 0.005s | Train Loss: 0.214651 |
# | Epoch: 175/500 | Train Time: 0.005s | Train Loss: 0.331466 |
# | Epoch: 176/500 | Train Time: 0.005s | Train Loss: 0.285032 |
# | Epoch: 177/500 | Train Time: 0.005s | Train Loss: 0.252408 |
# | Epoch: 178/500 | Train Time: 0.005s | Train Loss: 0.235466 |
# | Epoch: 179/500 | Train Time: 0.005s | Train Loss: 0.136322 |
# | Epoch: 180/500 | Train Time: 0.005s | Train Loss: 0.215659 |
# | Epoch: 181/500 | Train Time: 0.005s | Train Loss: 0.380731 |
# | Epoch: 182/500 | Train Time: 0.005s | Train Loss: 0.193905 |
# | Epoch: 183/500 | Train Time: 0.005s | Train Loss: 0.219940 |
# | Epoch: 184/500 | Train Time: 0.005s | Train Loss: 0.188179 |
# | Epoch: 185/500 | Train Time: 0.005s | Train Loss: 0.207687 |
# | Epoch: 186/500 | Train Time: 0.005s | Train Loss: 0.268214 |
# | Epoch: 187/500 | Train Time: 0.005s | Train Loss: 0.186736 |
# | Epoch: 188/500 | Train Time: 0.005s | Train Loss: 0.313478 |
# | Epoch: 189/500 | Train Time: 0.005s | Train Loss: 0.212184 |
# | Epoch: 190/500 | Train Time: 0.006s | Train Loss: 0.417383 |
# | Epoch: 191/500 | Train Time: 0.006s | Train Loss: 0.233515 |
# | Epoch: 192/500 | Train Time: 0.005s | Train Loss: 0.219062 |
# | Epoch: 193/500 | Train Time: 0.005s | Train Loss: 0.313675 |
# | Epoch: 194/500 | Train Time: 0.005s | Train Loss: 0.267865 |
# | Epoch: 195/500 | Train Time: 0.005s | Train Loss: 0.241980 |
# | Epoch: 196/500 | Train Time: 0.005s | Train Loss: 0.240895 |
# | Epoch: 197/500 | Train Time: 0.005s | Train Loss: 0.254131 |
# | Epoch: 198/500 | Train Time: 0.005s | Train Loss: 0.205121 |
# | Epoch: 199/500 | Train Time: 0.005s | Train Loss: 0.181021 |
# | Epoch: 200/500 | Train Time: 0.005s | Train Loss: 0.197801 |
# | Epoch: 201/500 | Train Time: 0.005s | Train Loss: 0.227976 |
# | Epoch: 202/500 | Train Time: 0.005s | Train Loss: 0.220953 |
# | Epoch: 203/500 | Train Time: 0.005s | Train Loss: 0.206956 |
# | Epoch: 204/500 | Train Time: 0.005s | Train Loss: 0.183271 |
# | Epoch: 205/500 | Train Time: 0.005s | Train Loss: 0.287141 |
# | Epoch: 206/500 | Train Time: 0.005s | Train Loss: 0.242625 |
# | Epoch: 207/500 | Train Time: 0.005s | Train Loss: 0.275175 |
# | Epoch: 208/500 | Train Time: 0.005s | Train Loss: 0.216458 |
# | Epoch: 209/500 | Train Time: 0.005s | Train Loss: 0.194514 |
# | Epoch: 210/500 | Train Time: 0.005s | Train Loss: 0.299614 |
# | Epoch: 211/500 | Train Time: 0.005s | Train Loss: 0.276144 |
# | Epoch: 212/500 | Train Time: 0.005s | Train Loss: 0.183797 |
# | Epoch: 213/500 | Train Time: 0.005s | Train Loss: 0.306649 |
# | Epoch: 214/500 | Train Time: 0.005s | Train Loss: 0.275755 |
# | Epoch: 215/500 | Train Time: 0.005s | Train Loss: 0.291856 |
# | Epoch: 216/500 | Train Time: 0.005s | Train Loss: 0.214283 |
# | Epoch: 217/500 | Train Time: 0.005s | Train Loss: 0.197805 |
# | Epoch: 218/500 | Train Time: 0.005s | Train Loss: 0.235479 |
# | Epoch: 219/500 | Train Time: 0.005s | Train Loss: 0.170797 |
# | Epoch: 220/500 | Train Time: 0.005s | Train Loss: 0.161125 |
# | Epoch: 221/500 | Train Time: 0.005s | Train Loss: 0.211899 |
# | Epoch: 222/500 | Train Time: 0.005s | Train Loss: 0.244966 |
# | Epoch: 223/500 | Train Time: 0.005s | Train Loss: 0.265872 |
# | Epoch: 224/500 | Train Time: 0.005s | Train Loss: 0.201255 |
# | Epoch: 225/500 | Train Time: 0.005s | Train Loss: 0.208637 |
# | Epoch: 226/500 | Train Time: 0.005s | Train Loss: 0.176775 |
# | Epoch: 227/500 | Train Time: 0.005s | Train Loss: 0.218320 |
# | Epoch: 228/500 | Train Time: 0.005s | Train Loss: 0.147262 |
# | Epoch: 229/500 | Train Time: 0.005s | Train Loss: 0.199693 |
# | Epoch: 230/500 | Train Time: 0.006s | Train Loss: 0.168817 |
# | Epoch: 231/500 | Train Time: 0.006s | Train Loss: 0.359408 |
# | Epoch: 232/500 | Train Time: 0.005s | Train Loss: 0.221638 |
# | Epoch: 233/500 | Train Time: 0.005s | Train Loss: 0.234819 |
# | Epoch: 234/500 | Train Time: 0.005s | Train Loss: 0.238952 |
# | Epoch: 235/500 | Train Time: 0.005s | Train Loss: 0.222827 |
# | Epoch: 236/500 | Train Time: 0.005s | Train Loss: 0.233990 |
# | Epoch: 237/500 | Train Time: 0.005s | Train Loss: 0.145781 |
# | Epoch: 238/500 | Train Time: 0.005s | Train Loss: 0.166276 |
# | Epoch: 239/500 | Train Time: 0.005s | Train Loss: 0.154865 |
# | Epoch: 240/500 | Train Time: 0.005s | Train Loss: 0.296186 |
# | Epoch: 241/500 | Train Time: 0.005s | Train Loss: 0.144545 |
# | Epoch: 242/500 | Train Time: 0.005s | Train Loss: 0.253196 |
# | Epoch: 243/500 | Train Time: 0.005s | Train Loss: 0.301187 |
# | Epoch: 244/500 | Train Time: 0.005s | Train Loss: 0.229533 |
# | Epoch: 245/500 | Train Time: 0.005s | Train Loss: 0.233291 |
# | Epoch: 246/500 | Train Time: 0.005s | Train Loss: 0.191566 |
# | Epoch: 247/500 | Train Time: 0.005s | Train Loss: 0.192222 |
# | Epoch: 248/500 | Train Time: 0.005s | Train Loss: 0.279836 |
# | Epoch: 249/500 | Train Time: 0.005s | Train Loss: 0.237664 |
# | Epoch: 250/500 | Train Time: 0.005s | Train Loss: 0.203151 |
#   LR scheduler: new learning rate is 1e-05
# | Epoch: 251/500 | Train Time: 0.005s | Train Loss: 0.197013 |
# | Epoch: 252/500 | Train Time: 0.005s | Train Loss: 0.174446 |
# | Epoch: 253/500 | Train Time: 0.005s | Train Loss: 0.244763 |
# | Epoch: 254/500 | Train Time: 0.005s | Train Loss: 0.145502 |
# | Epoch: 255/500 | Train Time: 0.005s | Train Loss: 0.226119 |
# | Epoch: 256/500 | Train Time: 0.005s | Train Loss: 0.134754 |
# | Epoch: 257/500 | Train Time: 0.005s | Train Loss: 0.115844 |
# | Epoch: 258/500 | Train Time: 0.005s | Train Loss: 0.161038 |
# | Epoch: 259/500 | Train Time: 0.006s | Train Loss: 0.210326 |
# | Epoch: 260/500 | Train Time: 0.005s | Train Loss: 0.193144 |
# | Epoch: 261/500 | Train Time: 0.005s | Train Loss: 0.170500 |
# | Epoch: 262/500 | Train Time: 0.005s | Train Loss: 0.209257 |
# | Epoch: 263/500 | Train Time: 0.005s | Train Loss: 0.195911 |
# | Epoch: 264/500 | Train Time: 0.005s | Train Loss: 0.113852 |
# | Epoch: 265/500 | Train Time: 0.005s | Train Loss: 0.142318 |
# | Epoch: 266/500 | Train Time: 0.005s | Train Loss: 0.174722 |
# | Epoch: 267/500 | Train Time: 0.005s | Train Loss: 0.194685 |
# | Epoch: 268/500 | Train Time: 0.005s | Train Loss: 0.165673 |
# | Epoch: 269/500 | Train Time: 0.006s | Train Loss: 0.201274 |
# | Epoch: 270/500 | Train Time: 0.006s | Train Loss: 0.250809 |
# | Epoch: 271/500 | Train Time: 0.006s | Train Loss: 0.183748 |
# | Epoch: 272/500 | Train Time: 0.005s | Train Loss: 0.147959 |
# | Epoch: 273/500 | Train Time: 0.005s | Train Loss: 0.159600 |
# | Epoch: 274/500 | Train Time: 0.005s | Train Loss: 0.216204 |
# | Epoch: 275/500 | Train Time: 0.005s | Train Loss: 0.138094 |
# | Epoch: 276/500 | Train Time: 0.005s | Train Loss: 0.191068 |
# | Epoch: 277/500 | Train Time: 0.005s | Train Loss: 0.194791 |
# | Epoch: 278/500 | Train Time: 0.005s | Train Loss: 0.116929 |
# | Epoch: 279/500 | Train Time: 0.006s | Train Loss: 0.168201 |
# | Epoch: 280/500 | Train Time: 0.006s | Train Loss: 0.169832 |
# | Epoch: 281/500 | Train Time: 0.005s | Train Loss: 0.221078 |
# | Epoch: 282/500 | Train Time: 0.005s | Train Loss: 0.214357 |
# | Epoch: 283/500 | Train Time: 0.005s | Train Loss: 0.157989 |
# | Epoch: 284/500 | Train Time: 0.005s | Train Loss: 0.148956 |
# | Epoch: 285/500 | Train Time: 0.005s | Train Loss: 0.186361 |
# | Epoch: 286/500 | Train Time: 0.005s | Train Loss: 0.134068 |
# | Epoch: 287/500 | Train Time: 0.005s | Train Loss: 0.152157 |
# | Epoch: 288/500 | Train Time: 0.005s | Train Loss: 0.150574 |
# | Epoch: 289/500 | Train Time: 0.005s | Train Loss: 0.173938 |
# | Epoch: 290/500 | Train Time: 0.005s | Train Loss: 0.179483 |
# | Epoch: 291/500 | Train Time: 0.005s | Train Loss: 0.146426 |
# | Epoch: 292/500 | Train Time: 0.005s | Train Loss: 0.147994 |
# | Epoch: 293/500 | Train Time: 0.005s | Train Loss: 0.133737 |
# | Epoch: 294/500 | Train Time: 0.005s | Train Loss: 0.213042 |
# | Epoch: 295/500 | Train Time: 0.005s | Train Loss: 0.214436 |
# | Epoch: 296/500 | Train Time: 0.005s | Train Loss: 0.190537 |
# | Epoch: 297/500 | Train Time: 0.005s | Train Loss: 0.125806 |
# | Epoch: 298/500 | Train Time: 0.006s | Train Loss: 0.172692 |
# | Epoch: 299/500 | Train Time: 0.005s | Train Loss: 0.159694 |
# | Epoch: 300/500 | Train Time: 0.005s | Train Loss: 0.205913 |
# | Epoch: 301/500 | Train Time: 0.005s | Train Loss: 0.187883 |
# | Epoch: 302/500 | Train Time: 0.005s | Train Loss: 0.206439 |
# | Epoch: 303/500 | Train Time: 0.005s | Train Loss: 0.136948 |
# | Epoch: 304/500 | Train Time: 0.005s | Train Loss: 0.140014 |
# | Epoch: 305/500 | Train Time: 0.005s | Train Loss: 0.179309 |
# | Epoch: 306/500 | Train Time: 0.005s | Train Loss: 0.211620 |
# | Epoch: 307/500 | Train Time: 0.005s | Train Loss: 0.140847 |
# | Epoch: 308/500 | Train Time: 0.005s | Train Loss: 0.150707 |
# | Epoch: 309/500 | Train Time: 0.005s | Train Loss: 0.168165 |
# | Epoch: 310/500 | Train Time: 0.006s | Train Loss: 0.160475 |
# | Epoch: 311/500 | Train Time: 0.005s | Train Loss: 0.187859 |
# | Epoch: 312/500 | Train Time: 0.005s | Train Loss: 0.175607 |
# | Epoch: 313/500 | Train Time: 0.005s | Train Loss: 0.196438 |
# | Epoch: 314/500 | Train Time: 0.005s | Train Loss: 0.135804 |
# | Epoch: 315/500 | Train Time: 0.005s | Train Loss: 0.152100 |
# | Epoch: 316/500 | Train Time: 0.005s | Train Loss: 0.158251 |
# | Epoch: 317/500 | Train Time: 0.005s | Train Loss: 0.213682 |
# | Epoch: 318/500 | Train Time: 0.005s | Train Loss: 0.247289 |
# | Epoch: 319/500 | Train Time: 0.005s | Train Loss: 0.142266 |
# | Epoch: 320/500 | Train Time: 0.005s | Train Loss: 0.194544 |
# | Epoch: 321/500 | Train Time: 0.005s | Train Loss: 0.184603 |
# | Epoch: 322/500 | Train Time: 0.005s | Train Loss: 0.184133 |
# | Epoch: 323/500 | Train Time: 0.005s | Train Loss: 0.138277 |
# | Epoch: 324/500 | Train Time: 0.005s | Train Loss: 0.168576 |
# | Epoch: 325/500 | Train Time: 0.005s | Train Loss: 0.143912 |
# | Epoch: 326/500 | Train Time: 0.005s | Train Loss: 0.225660 |
# | Epoch: 327/500 | Train Time: 0.005s | Train Loss: 0.158644 |
# | Epoch: 328/500 | Train Time: 0.005s | Train Loss: 0.175200 |
# | Epoch: 329/500 | Train Time: 0.005s | Train Loss: 0.201364 |
# | Epoch: 330/500 | Train Time: 0.005s | Train Loss: 0.187100 |
# | Epoch: 331/500 | Train Time: 0.005s | Train Loss: 0.130807 |
# | Epoch: 332/500 | Train Time: 0.005s | Train Loss: 0.169158 |
# | Epoch: 333/500 | Train Time: 0.005s | Train Loss: 0.222712 |
# | Epoch: 334/500 | Train Time: 0.005s | Train Loss: 0.179067 |
# | Epoch: 335/500 | Train Time: 0.005s | Train Loss: 0.227783 |
# | Epoch: 336/500 | Train Time: 0.005s | Train Loss: 0.142396 |
# | Epoch: 337/500 | Train Time: 0.005s | Train Loss: 0.177621 |
# | Epoch: 338/500 | Train Time: 0.005s | Train Loss: 0.126383 |
# | Epoch: 339/500 | Train Time: 0.005s | Train Loss: 0.158606 |
# | Epoch: 340/500 | Train Time: 0.005s | Train Loss: 0.227296 |
# | Epoch: 341/500 | Train Time: 0.005s | Train Loss: 0.184362 |
# | Epoch: 342/500 | Train Time: 0.005s | Train Loss: 0.162035 |
# | Epoch: 343/500 | Train Time: 0.005s | Train Loss: 0.199255 |
# | Epoch: 344/500 | Train Time: 0.005s | Train Loss: 0.181901 |
# | Epoch: 345/500 | Train Time: 0.005s | Train Loss: 0.098145 |
# | Epoch: 346/500 | Train Time: 0.005s | Train Loss: 0.153513 |
# | Epoch: 347/500 | Train Time: 0.005s | Train Loss: 0.169745 |
# | Epoch: 348/500 | Train Time: 0.005s | Train Loss: 0.204418 |
# | Epoch: 349/500 | Train Time: 0.005s | Train Loss: 0.137592 |
# | Epoch: 350/500 | Train Time: 0.006s | Train Loss: 0.199799 |
# | Epoch: 351/500 | Train Time: 0.005s | Train Loss: 0.181755 |
# | Epoch: 352/500 | Train Time: 0.005s | Train Loss: 0.161088 |
# | Epoch: 353/500 | Train Time: 0.005s | Train Loss: 0.129945 |
# | Epoch: 354/500 | Train Time: 0.005s | Train Loss: 0.151524 |
# | Epoch: 355/500 | Train Time: 0.005s | Train Loss: 0.120119 |
# | Epoch: 356/500 | Train Time: 0.005s | Train Loss: 0.192814 |
# | Epoch: 357/500 | Train Time: 0.005s | Train Loss: 0.146899 |
# | Epoch: 358/500 | Train Time: 0.005s | Train Loss: 0.119832 |
# | Epoch: 359/500 | Train Time: 0.005s | Train Loss: 0.188706 |
# | Epoch: 360/500 | Train Time: 0.005s | Train Loss: 0.219548 |
# | Epoch: 361/500 | Train Time: 0.005s | Train Loss: 0.171305 |
# | Epoch: 362/500 | Train Time: 0.005s | Train Loss: 0.178055 |
# | Epoch: 363/500 | Train Time: 0.005s | Train Loss: 0.150373 |
# | Epoch: 364/500 | Train Time: 0.005s | Train Loss: 0.175814 |
# | Epoch: 365/500 | Train Time: 0.005s | Train Loss: 0.233804 |
# | Epoch: 366/500 | Train Time: 0.005s | Train Loss: 0.187056 |
# | Epoch: 367/500 | Train Time: 0.005s | Train Loss: 0.158908 |
# | Epoch: 368/500 | Train Time: 0.005s | Train Loss: 0.153878 |
# | Epoch: 369/500 | Train Time: 0.005s | Train Loss: 0.123296 |
# | Epoch: 370/500 | Train Time: 0.005s | Train Loss: 0.111143 |
# | Epoch: 371/500 | Train Time: 0.005s | Train Loss: 0.189559 |
# | Epoch: 372/500 | Train Time: 0.005s | Train Loss: 0.140639 |
# | Epoch: 373/500 | Train Time: 0.005s | Train Loss: 0.196382 |
# | Epoch: 374/500 | Train Time: 0.005s | Train Loss: 0.155556 |
# | Epoch: 375/500 | Train Time: 0.005s | Train Loss: 0.181721 |
# | Epoch: 376/500 | Train Time: 0.005s | Train Loss: 0.250901 |
# | Epoch: 377/500 | Train Time: 0.005s | Train Loss: 0.161813 |
# | Epoch: 378/500 | Train Time: 0.005s | Train Loss: 0.221309 |
# | Epoch: 379/500 | Train Time: 0.005s | Train Loss: 0.148451 |
# | Epoch: 380/500 | Train Time: 0.005s | Train Loss: 0.148385 |
# | Epoch: 381/500 | Train Time: 0.005s | Train Loss: 0.162269 |
# | Epoch: 382/500 | Train Time: 0.005s | Train Loss: 0.119552 |
# | Epoch: 383/500 | Train Time: 0.005s | Train Loss: 0.169643 |
# | Epoch: 384/500 | Train Time: 0.005s | Train Loss: 0.208550 |
# | Epoch: 385/500 | Train Time: 0.005s | Train Loss: 0.163691 |
# | Epoch: 386/500 | Train Time: 0.005s | Train Loss: 0.243732 |
# | Epoch: 387/500 | Train Time: 0.005s | Train Loss: 0.145200 |
# | Epoch: 388/500 | Train Time: 0.005s | Train Loss: 0.138247 |
# | Epoch: 389/500 | Train Time: 0.005s | Train Loss: 0.151951 |
# | Epoch: 390/500 | Train Time: 0.006s | Train Loss: 0.138498 |
# | Epoch: 391/500 | Train Time: 0.005s | Train Loss: 0.192806 |
# | Epoch: 392/500 | Train Time: 0.005s | Train Loss: 0.143388 |
# | Epoch: 393/500 | Train Time: 0.005s | Train Loss: 0.184226 |
# | Epoch: 394/500 | Train Time: 0.005s | Train Loss: 0.142441 |
# | Epoch: 395/500 | Train Time: 0.005s | Train Loss: 0.146254 |
# | Epoch: 396/500 | Train Time: 0.005s | Train Loss: 0.136144 |
# | Epoch: 397/500 | Train Time: 0.005s | Train Loss: 0.170727 |
# | Epoch: 398/500 | Train Time: 0.006s | Train Loss: 0.124761 |
# | Epoch: 399/500 | Train Time: 0.005s | Train Loss: 0.155192 |
# | Epoch: 400/500 | Train Time: 0.005s | Train Loss: 0.186044 |
# | Epoch: 401/500 | Train Time: 0.005s | Train Loss: 0.134930 |
# | Epoch: 402/500 | Train Time: 0.005s | Train Loss: 0.174981 |
# | Epoch: 403/500 | Train Time: 0.005s | Train Loss: 0.152533 |
# | Epoch: 404/500 | Train Time: 0.005s | Train Loss: 0.128698 |
# | Epoch: 405/500 | Train Time: 0.005s | Train Loss: 0.172016 |
# | Epoch: 406/500 | Train Time: 0.005s | Train Loss: 0.149128 |
# | Epoch: 407/500 | Train Time: 0.005s | Train Loss: 0.184835 |
# | Epoch: 408/500 | Train Time: 0.005s | Train Loss: 0.133623 |
# | Epoch: 409/500 | Train Time: 0.005s | Train Loss: 0.156313 |
# | Epoch: 410/500 | Train Time: 0.005s | Train Loss: 0.181384 |
# | Epoch: 411/500 | Train Time: 0.005s | Train Loss: 0.124598 |
# | Epoch: 412/500 | Train Time: 0.005s | Train Loss: 0.213822 |
# | Epoch: 413/500 | Train Time: 0.005s | Train Loss: 0.263726 |
# | Epoch: 414/500 | Train Time: 0.005s | Train Loss: 0.231719 |
# | Epoch: 415/500 | Train Time: 0.005s | Train Loss: 0.124158 |
# | Epoch: 416/500 | Train Time: 0.005s | Train Loss: 0.299921 |
# | Epoch: 417/500 | Train Time: 0.005s | Train Loss: 0.167849 |
# | Epoch: 418/500 | Train Time: 0.005s | Train Loss: 0.223073 |
# | Epoch: 419/500 | Train Time: 0.005s | Train Loss: 0.154303 |
# | Epoch: 420/500 | Train Time: 0.005s | Train Loss: 0.187843 |
# | Epoch: 421/500 | Train Time: 0.005s | Train Loss: 0.213038 |
# | Epoch: 422/500 | Train Time: 0.005s | Train Loss: 0.180905 |
# | Epoch: 423/500 | Train Time: 0.005s | Train Loss: 0.134685 |
# | Epoch: 424/500 | Train Time: 0.005s | Train Loss: 0.128801 |
# | Epoch: 425/500 | Train Time: 0.005s | Train Loss: 0.175003 |
# | Epoch: 426/500 | Train Time: 0.005s | Train Loss: 0.245687 |
# | Epoch: 427/500 | Train Time: 0.005s | Train Loss: 0.209226 |
# | Epoch: 428/500 | Train Time: 0.005s | Train Loss: 0.178191 |
# | Epoch: 429/500 | Train Time: 0.005s | Train Loss: 0.178628 |
# | Epoch: 430/500 | Train Time: 0.006s | Train Loss: 0.142248 |
# | Epoch: 431/500 | Train Time: 0.006s | Train Loss: 0.186305 |
# | Epoch: 432/500 | Train Time: 0.005s | Train Loss: 0.133580 |
# | Epoch: 433/500 | Train Time: 0.005s | Train Loss: 0.181700 |
# | Epoch: 434/500 | Train Time: 0.005s | Train Loss: 0.194087 |
# | Epoch: 435/500 | Train Time: 0.005s | Train Loss: 0.205790 |
# | Epoch: 436/500 | Train Time: 0.005s | Train Loss: 0.135627 |
# | Epoch: 437/500 | Train Time: 0.005s | Train Loss: 0.142712 |
# | Epoch: 438/500 | Train Time: 0.006s | Train Loss: 0.146723 |
# | Epoch: 439/500 | Train Time: 0.005s | Train Loss: 0.144922 |
# | Epoch: 440/500 | Train Time: 0.005s | Train Loss: 0.184823 |
# | Epoch: 441/500 | Train Time: 0.005s | Train Loss: 0.165500 |
# | Epoch: 442/500 | Train Time: 0.005s | Train Loss: 0.185032 |
# | Epoch: 443/500 | Train Time: 0.005s | Train Loss: 0.149241 |
# | Epoch: 444/500 | Train Time: 0.005s | Train Loss: 0.257370 |
# | Epoch: 445/500 | Train Time: 0.005s | Train Loss: 0.154541 |
# | Epoch: 446/500 | Train Time: 0.005s | Train Loss: 0.185005 |
# | Epoch: 447/500 | Train Time: 0.005s | Train Loss: 0.206151 |
# | Epoch: 448/500 | Train Time: 0.005s | Train Loss: 0.154848 |
# | Epoch: 449/500 | Train Time: 0.005s | Train Loss: 0.153901 |
# | Epoch: 450/500 | Train Time: 0.005s | Train Loss: 0.106702 |
# | Epoch: 451/500 | Train Time: 0.005s | Train Loss: 0.157752 |
# | Epoch: 452/500 | Train Time: 0.005s | Train Loss: 0.141766 |
# | Epoch: 453/500 | Train Time: 0.005s | Train Loss: 0.139849 |
# | Epoch: 454/500 | Train Time: 0.005s | Train Loss: 0.160910 |
# | Epoch: 455/500 | Train Time: 0.005s | Train Loss: 0.159860 |
# | Epoch: 456/500 | Train Time: 0.005s | Train Loss: 0.173401 |
# | Epoch: 457/500 | Train Time: 0.005s | Train Loss: 0.208717 |
# | Epoch: 458/500 | Train Time: 0.005s | Train Loss: 0.141817 |
# | Epoch: 459/500 | Train Time: 0.005s | Train Loss: 0.182323 |
# | Epoch: 460/500 | Train Time: 0.005s | Train Loss: 0.219042 |
# | Epoch: 461/500 | Train Time: 0.005s | Train Loss: 0.162010 |
# | Epoch: 462/500 | Train Time: 0.005s | Train Loss: 0.195673 |
# | Epoch: 463/500 | Train Time: 0.005s | Train Loss: 0.111734 |
# | Epoch: 464/500 | Train Time: 0.005s | Train Loss: 0.201269 |
# | Epoch: 465/500 | Train Time: 0.005s | Train Loss: 0.129294 |
# | Epoch: 466/500 | Train Time: 0.005s | Train Loss: 0.169371 |
# | Epoch: 467/500 | Train Time: 0.005s | Train Loss: 0.135920 |
# | Epoch: 468/500 | Train Time: 0.005s | Train Loss: 0.113946 |
# | Epoch: 469/500 | Train Time: 0.006s | Train Loss: 0.163374 |
# | Epoch: 470/500 | Train Time: 0.006s | Train Loss: 0.150147 |
# | Epoch: 471/500 | Train Time: 0.005s | Train Loss: 0.118283 |
# | Epoch: 472/500 | Train Time: 0.005s | Train Loss: 0.139165 |
# | Epoch: 473/500 | Train Time: 0.005s | Train Loss: 0.182274 |
# | Epoch: 474/500 | Train Time: 0.005s | Train Loss: 0.204641 |
# | Epoch: 475/500 | Train Time: 0.006s | Train Loss: 0.132317 |
# | Epoch: 476/500 | Train Time: 0.006s | Train Loss: 0.237341 |
# | Epoch: 477/500 | Train Time: 0.005s | Train Loss: 0.192654 |
# | Epoch: 478/500 | Train Time: 0.005s | Train Loss: 0.181138 |
# | Epoch: 479/500 | Train Time: 0.006s | Train Loss: 0.155085 |
# | Epoch: 480/500 | Train Time: 0.005s | Train Loss: 0.256170 |
# | Epoch: 481/500 | Train Time: 0.005s | Train Loss: 0.168606 |
# | Epoch: 482/500 | Train Time: 0.005s | Train Loss: 0.138559 |
# | Epoch: 483/500 | Train Time: 0.005s | Train Loss: 0.134744 |
# | Epoch: 484/500 | Train Time: 0.005s | Train Loss: 0.225249 |
# | Epoch: 485/500 | Train Time: 0.006s | Train Loss: 0.200471 |
# | Epoch: 486/500 | Train Time: 0.005s | Train Loss: 0.130991 |
# | Epoch: 487/500 | Train Time: 0.005s | Train Loss: 0.190408 |
# | Epoch: 488/500 | Train Time: 0.005s | Train Loss: 0.178286 |
# | Epoch: 489/500 | Train Time: 0.005s | Train Loss: 0.145411 |
# | Epoch: 490/500 | Train Time: 0.005s | Train Loss: 0.241272 |
# | Epoch: 491/500 | Train Time: 0.005s | Train Loss: 0.153706 |
# | Epoch: 492/500 | Train Time: 0.005s | Train Loss: 0.178694 |
# | Epoch: 493/500 | Train Time: 0.005s | Train Loss: 0.149152 |
# | Epoch: 494/500 | Train Time: 0.006s | Train Loss: 0.232575 |
# | Epoch: 495/500 | Train Time: 0.005s | Train Loss: 0.130505 |
# | Epoch: 496/500 | Train Time: 0.005s | Train Loss: 0.138639 |
# | Epoch: 497/500 | Train Time: 0.005s | Train Loss: 0.168628 |
# | Epoch: 498/500 | Train Time: 0.005s | Train Loss: 0.140393 |
# | Epoch: 499/500 | Train Time: 0.005s | Train Loss: 0.135280 |
# | Epoch: 500/500 | Train Time: 0.005s | Train Loss: 0.183781 |
# Training Time: 2.604s
# Finished training.

# %%
plot_loss_moment(deepSVDD.loss_plot)

# %%
# Test model
deepSVDD.test(test_loader, device=device, n_jobs_dataloader=config['n_jobs_dataloader'])
# Out:
# Starting testing...
# Test AUC: 67.96%
# Test Time: 0.005s
# Finished testing.

# %%
# Save results, model, and configuration
deepSVDD.save_results(export_json= config["export_path"] + '/results.json')
deepSVDD.save_model(export_model=config["export_path"] + '/model.tar', save_ae = True)

# %%
labels, scores = zip(*deepSVDD.results['test_scores'])
labels, scores = np.array(labels), np.array(scores)

# %%
import pandas as pd

result_df = pd.DataFrame()
result_df['labels'] = labels
result_df['scores'] = scores

label_normal = [0]
label_abnormal = [1]

df_normal = result_df[result_df.labels == 0]
df_abnormal = result_df[result_df.labels == 1]

# %%
cut_90 = df_normal.scores.quantile(0.90)
y_90 = [1 if e > cut_90 else 0 for e in df_abnormal['scores'].values]

cut_85 = df_normal.scores.quantile(0.85)
y_85 = [1 if e > cut_85 else 0 for e in df_abnormal['scores'].values]

cut_80 = df_normal.scores.quantile(0.80)
y_80 = [1 if e > cut_80 else 0 for e in df_abnormal['scores'].values]

# %%
print("Binary F1 Score:", f1_score(y_90, np.ones_like(y_90), average = 'binary'))
print("Binary F1 Score:", f1_score(y_85, np.ones_like(y_85), average = 'binary'))
print("Binary F1 Score:", f1_score(y_80, np.ones_like(y_80), average = 'binary'))
# Out:
# Binary F1 Score: 0.42857142857142855
# Binary F1 Score: 0.5806451612903226
# Binary F1 Score: 0.625
